# %% [markdown]
# # Compare embeddings performance
#
# We use different approaches to create embeddings from the same texts and compare their performance.
#
# ## Dependencies
#
# To run the required vector database locally, use this command:
# `docker run --name 04-compare-embeddings-demo-vectordb -p 6333:6333 -p 6334:6334 -d qdrant/qdrant`

# %%
# %pip install chromadb
# %pip install langchain
# %pip install langchain-community
# %pip install langchain-chroma
# %pip install langchain-huggingface
# %pip install langchain-openai
# %pip install pickleshare
# %pip install qdrant-client
# %pip install tabulate
# Out:
# Requirement already satisfied: chromadb in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (0.6.3)
# Requirement already satisfied: build>=1.0.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (3.20.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (1.31.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.46.1)
# Requirement already satisfied: anyio in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.8.0)
# Requirement already satisfied: certifi in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-proto==1.31.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: opentelemetry-util-http==0.52b0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.52b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.52b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.29.3)
# Requirement already satisfied: click>=8.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: zipp>=3.20 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (0.3.20)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain) (0.3.45)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain) (0.3.15)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: anyio in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-community in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (0.3.19)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (0.3.45)
# Requirement already satisfied: langchain<1.0.0,>=0.3.20 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (0.3.20)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (0.3.15)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.20->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.41->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: anyio in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.20->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-chroma in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-chroma) (0.3.45)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-chroma) (0.6.3)
# Requirement already satisfied: build>=1.0.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.10.6)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.20.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.31.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.31.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.52b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.31.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (13.9.4)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (0.3.15)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (24.2)
# Requirement already satisfied: pyproject_hooks in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.46.1)
# Requirement already satisfied: anyio in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.8.0)
# Requirement already satisfied: certifi in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.7)
# Requirement already satisfied: idna in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (1.0.0)
# ...
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2025.1.31)
# Requirement already satisfied: networkx in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.6.0)
# Requirement already satisfied: anyio in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain-huggingface) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-openai in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (0.3.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.42 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-openai) (0.3.45)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-openai) (1.66.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.42->langchain-openai) (0.3.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.42->langchain-openai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.42->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.42->langchain-openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.42->langchain-openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.42->langchain-openai) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.42->langchain-openai) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.8.2)
# Requirement already satisfied: sniffio in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.42->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.42->langchain-openai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.42->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.42->langchain-openai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.42->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.42->langchain-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pickleshare in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (0.7.5)
# Note: you may need to restart the kernel to use updated packages.
# Collecting qdrant-client
#   Downloading qdrant_client-1.13.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: grpcio>=1.41.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from qdrant-client) (1.71.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /Users/christianweyer/.local/lib/python3.11/site-packages (from qdrant-client) (1.62.1)
# Requirement already satisfied: httpx>=0.20.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=1.21 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from qdrant-client) (1.26.4)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pydantic>=1.10.8 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from qdrant-client) (2.10.6)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from qdrant-client) (2.3.0)
# Collecting protobuf<5.0dev,>=4.21.6 (from grpcio-tools>=1.41.0->qdrant-client)
#   Downloading protobuf-4.25.6-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from grpcio-tools>=1.41.0->qdrant-client) (75.8.0)
# Requirement already satisfied: anyio in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.8.0)
# Requirement already satisfied: certifi in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.7)
# Requirement already satisfied: idna in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.14.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client)
#   Downloading h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic>=1.10.8->qdrant-client) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from pydantic>=1.10.8->qdrant-client) (4.12.2)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: sniffio>=1.1 in /Users/christianweyer/Sources/gen-ai-customer-workshop-november-2024/.conda/lib/python3.11/site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.3.1)
# Downloading qdrant_client-1.13.3-py3-none-any.whl (306 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading h2-4.2.0-py3-none-any.whl (60 kB)
# Downloading protobuf-4.25.6-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: protobuf, portalocker, hyperframe, hpack, h2, qdrant-client
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.31.0 requires protobuf<6.0,>=5.0, but you have protobuf 4.25.6 which is incompatible.
# Successfully installed h2-4.2.0 hpack-4.1.0 hyperframe-6.1.0 portalocker-2.10.1 protobuf-4.25.6 qdrant-client-1.13.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Configuration:
#
# Please select the model you want to use for the transformations.

# %%
llm_source = "openai" # openai or hf for huggingface
embedding_source = "openai" # openai or hf for huggingface

llm_model = "gpt-4o"
temperature = 0

embeddings_model = "text-embedding-3-large"

markdown_documents_path = "../../../../tt-readme"

use_cached_documents = False
use_cached_transforms = False
reindex_documents = True

# %% [markdown]
# ## Test different approaches of indexing
#
# This will
# - create a question for each document,
# - create an answer for each document and
# - summarize each document

# %% [markdown]
# ## Load and split markdown contents of the TT Readme

# %%
if use_cached_documents:
    print("Skipping loading documents from markdown files")
else:

    from langchain.document_loaders import DirectoryLoader, TextLoader
    from langchain.text_splitter import MarkdownHeaderTextSplitter

    readme_documents = DirectoryLoader(
        markdown_documents_path,
        glob="**/*.md",
        loader_cls=TextLoader
        ).load()

    headers_to_split_on = [
        ("#", "Header 1"),
        ("##", "Header 2"),
    ]

    splitter = MarkdownHeaderTextSplitter(headers_to_split_on)

    split_documents = []
    for doc in readme_documents:
        result = splitter.split_text(doc.page_content)

        if isinstance(result, list):
            for res in result:
                res.metadata.update(doc.metadata)
            split_documents.extend(result)
        else:
            result.metadata.update(doc.metadata)
            split_documents.append(result)

    # For brevity, reduce amount of entries to a few only
    # split_documents = split_documents[50:60]

    index  = 1
    for doc in split_documents:
        doc.metadata["index"] = index
        index += 1
        doc.metadata["original_content"] = doc.page_content
        #print(doc.metadata)
        #print("\n")

# %% [markdown]
# ### Persist the data to files or load cached files

# %%
import pickle

if (use_cached_documents):
    print("Loading documents from file")
    with open("./cache/split_documents.pickle", "rb") as f:
        split_documents = pickle.load(f)
else:
    print("Writing documents to file")
    with open("./cache/split_documents.pickle", "wb") as f:
        pickle.dump(split_documents, f)
# Out:
# Writing documents to file

# %% [markdown]
# ## Massage content into new embedding documents

# %%
from langchain_openai import ChatOpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

llm = ChatOpenAI(model=llm_model, temperature=temperature)

def build_chain(prompt):
    return LLMChain(llm=llm, prompt=PromptTemplate(input_variables=["input"], template=prompt))

question_chain = build_chain("Formuliere drei verschiedene deutsche Fragen, die der folgende Text beantwortet: {input}")
answer_chain = build_chain("Erkläre in zwei bis drei deutschen Sätzen, was der folgende Text beantwortet: {input}")
summarize_chain = build_chain("Erstelle eine kurze deutsche Zusammenfassung des folgenden Textes: {input}")
# Out:
# /var/folders/5l/mksr7zj10lgb4y62_h1x1nxc0000gn/T/ipykernel_79266/4177760980.py:8: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   return LLMChain(llm=llm, prompt=PromptTemplate(input_variables=["input"], template=prompt))

# %%
import copy

def transform_documents(chain, file):
    if use_cached_transforms:
        print(f"Loading cached file {file}")
        with open(f"cache/{llm_model}_{file}_documents.pickle", "rb") as f:
            result = pickle.load(f)
        return result
    else:
        result = copy.deepcopy(split_documents)
        for doc in result:
            print(f"Transforming {file} document {doc.metadata['index']} with model {llm_model}")
            doc.metadata["original_content"] = copy.copy(doc.page_content)
            doc.page_content = chain.run(doc.page_content)
        print(f"Writing {file} documents from model {llm_model} to file")
        with open(f"cache/{llm_model}_{file}_documents.pickle", "wb") as f:
            pickle.dump(result, f)
        return result

question_documents = transform_documents(question_chain, "questions")
answer_documents = transform_documents(answer_chain, "answers")
summary_documents = transform_documents(summarize_chain, "summaries")
# Out:
# Transforming questions document 1 with model gpt-4o
# /var/folders/5l/mksr7zj10lgb4y62_h1x1nxc0000gn/T/ipykernel_79266/3189603298.py:14: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   doc.page_content = chain.run(doc.page_content)
# Transforming questions document 2 with model gpt-4o
# Transforming questions document 3 with model gpt-4o
# Transforming questions document 4 with model gpt-4o
# Transforming questions document 5 with model gpt-4o
# Transforming questions document 6 with model gpt-4o
# Transforming questions document 7 with model gpt-4o
# Transforming questions document 8 with model gpt-4o
# Transforming questions document 9 with model gpt-4o
# Transforming questions document 10 with model gpt-4o
# Transforming questions document 11 with model gpt-4o
# Transforming questions document 12 with model gpt-4o
# Transforming questions document 13 with model gpt-4o
# Transforming questions document 14 with model gpt-4o
# Transforming questions document 15 with model gpt-4o
# Transforming questions document 16 with model gpt-4o
# Transforming questions document 17 with model gpt-4o
# Transforming questions document 18 with model gpt-4o
# Transforming questions document 19 with model gpt-4o
# Transforming questions document 20 with model gpt-4o
# Transforming questions document 21 with model gpt-4o
# Transforming questions document 22 with model gpt-4o
# Transforming questions document 23 with model gpt-4o
# Transforming questions document 24 with model gpt-4o
# Transforming questions document 25 with model gpt-4o
# Transforming questions document 26 with model gpt-4o
# Transforming questions document 27 with model gpt-4o
# Transforming questions document 28 with model gpt-4o
# Transforming questions document 29 with model gpt-4o
# Transforming questions document 30 with model gpt-4o
# Transforming questions document 31 with model gpt-4o
# Transforming questions document 32 with model gpt-4o
# Transforming questions document 33 with model gpt-4o
# Transforming questions document 34 with model gpt-4o
# Transforming questions document 35 with model gpt-4o
# Transforming questions document 36 with model gpt-4o
# Transforming questions document 37 with model gpt-4o
# Transforming questions document 38 with model gpt-4o
# Transforming questions document 39 with model gpt-4o
# Transforming questions document 40 with model gpt-4o
# Transforming questions document 41 with model gpt-4o
# Transforming questions document 42 with model gpt-4o
# Transforming questions document 43 with model gpt-4o
# Transforming questions document 44 with model gpt-4o
# Transforming questions document 45 with model gpt-4o
# Transforming questions document 46 with model gpt-4o
# Transforming questions document 47 with model gpt-4o
# Transforming questions document 48 with model gpt-4o
# Transforming questions document 49 with model gpt-4o
# Transforming questions document 50 with model gpt-4o
# Transforming questions document 51 with model gpt-4o
# Transforming questions document 52 with model gpt-4o
# Transforming questions document 53 with model gpt-4o
# Transforming questions document 54 with model gpt-4o
# Transforming questions document 55 with model gpt-4o
# Transforming questions document 56 with model gpt-4o
# Transforming questions document 57 with model gpt-4o
# Transforming questions document 58 with model gpt-4o
# Transforming questions document 59 with model gpt-4o
# Transforming questions document 60 with model gpt-4o
# Transforming questions document 61 with model gpt-4o
# Transforming questions document 62 with model gpt-4o
# Transforming questions document 63 with model gpt-4o
# Transforming questions document 64 with model gpt-4o
# Transforming questions document 65 with model gpt-4o
# Transforming questions document 66 with model gpt-4o
# Transforming questions document 67 with model gpt-4o
# Transforming questions document 68 with model gpt-4o
# Transforming questions document 69 with model gpt-4o
# Transforming questions document 70 with model gpt-4o
# Transforming questions document 71 with model gpt-4o
# Transforming questions document 72 with model gpt-4o
# Transforming questions document 73 with model gpt-4o
# Transforming questions document 74 with model gpt-4o
# Transforming questions document 75 with model gpt-4o
# Transforming questions document 76 with model gpt-4o
# Transforming questions document 77 with model gpt-4o
# Transforming questions document 78 with model gpt-4o
# Transforming questions document 79 with model gpt-4o
# Transforming questions document 80 with model gpt-4o
# Transforming questions document 81 with model gpt-4o
# Transforming questions document 82 with model gpt-4o
# Transforming questions document 83 with model gpt-4o
# Transforming questions document 84 with model gpt-4o
# Transforming questions document 85 with model gpt-4o
# Transforming questions document 86 with model gpt-4o
# Transforming questions document 87 with model gpt-4o
# Transforming questions document 88 with model gpt-4o
# Transforming questions document 89 with model gpt-4o
# Transforming questions document 90 with model gpt-4o
# Transforming questions document 91 with model gpt-4o
# Transforming questions document 92 with model gpt-4o
# Transforming questions document 93 with model gpt-4o
# Transforming questions document 94 with model gpt-4o
# Transforming questions document 95 with model gpt-4o
# Transforming questions document 96 with model gpt-4o
# Transforming questions document 97 with model gpt-4o
# Transforming questions document 98 with model gpt-4o
# Transforming questions document 99 with model gpt-4o
# Transforming questions document 100 with model gpt-4o
# Transforming questions document 101 with model gpt-4o
# Transforming questions document 102 with model gpt-4o
# Transforming questions document 103 with model gpt-4o
# Transforming questions document 104 with model gpt-4o
# Transforming questions document 105 with model gpt-4o
# Transforming questions document 106 with model gpt-4o
# Transforming questions document 107 with model gpt-4o
# Transforming questions document 108 with model gpt-4o
# Transforming questions document 109 with model gpt-4o
# Transforming questions document 110 with model gpt-4o
# Transforming questions document 111 with model gpt-4o
# Transforming questions document 112 with model gpt-4o
# Transforming questions document 113 with model gpt-4o
# Transforming questions document 114 with model gpt-4o
# Transforming questions document 115 with model gpt-4o
# Transforming questions document 116 with model gpt-4o
# Transforming questions document 117 with model gpt-4o
# Transforming questions document 118 with model gpt-4o
# Transforming questions document 119 with model gpt-4o
# Transforming questions document 120 with model gpt-4o
# Transforming questions document 121 with model gpt-4o
# Transforming questions document 122 with model gpt-4o
# Transforming questions document 123 with model gpt-4o
# Transforming questions document 124 with model gpt-4o
# Transforming questions document 125 with model gpt-4o
# Transforming questions document 126 with model gpt-4o
# Transforming questions document 127 with model gpt-4o
# Transforming questions document 128 with model gpt-4o
# Transforming questions document 129 with model gpt-4o
# Transforming questions document 130 with model gpt-4o
# Transforming questions document 131 with model gpt-4o
# Transforming questions document 132 with model gpt-4o
# Transforming questions document 133 with model gpt-4o
# Transforming questions document 134 with model gpt-4o
# Transforming questions document 135 with model gpt-4o
# Transforming questions document 136 with model gpt-4o
# Transforming questions document 137 with model gpt-4o
# Transforming questions document 138 with model gpt-4o
# Transforming questions document 139 with model gpt-4o
# Transforming questions document 140 with model gpt-4o
# Transforming questions document 141 with model gpt-4o
# Transforming questions document 142 with model gpt-4o
# Transforming questions document 143 with model gpt-4o
# Transforming questions document 144 with model gpt-4o
# Transforming questions document 145 with model gpt-4o
# Transforming questions document 146 with model gpt-4o
# Transforming questions document 147 with model gpt-4o
# Transforming questions document 148 with model gpt-4o
# Transforming questions document 149 with model gpt-4o
# Transforming questions document 150 with model gpt-4o
# Transforming questions document 151 with model gpt-4o
# Transforming questions document 152 with model gpt-4o
# Transforming questions document 153 with model gpt-4o
# Transforming questions document 154 with model gpt-4o
# Transforming questions document 155 with model gpt-4o
# Transforming questions document 156 with model gpt-4o
# Transforming questions document 157 with model gpt-4o
# Transforming questions document 158 with model gpt-4o
# Transforming questions document 159 with model gpt-4o
# Transforming questions document 160 with model gpt-4o
# Transforming questions document 161 with model gpt-4o
# Transforming questions document 162 with model gpt-4o
# Transforming questions document 163 with model gpt-4o
# Transforming questions document 164 with model gpt-4o
# Transforming questions document 165 with model gpt-4o
# Transforming questions document 166 with model gpt-4o
# Transforming questions document 167 with model gpt-4o
# Transforming questions document 168 with model gpt-4o
# Transforming questions document 169 with model gpt-4o
# Transforming questions document 170 with model gpt-4o
# Transforming questions document 171 with model gpt-4o
# Transforming questions document 172 with model gpt-4o
# Transforming questions document 173 with model gpt-4o
# Transforming questions document 174 with model gpt-4o
# Transforming questions document 175 with model gpt-4o
# Transforming questions document 176 with model gpt-4o
# Transforming questions document 177 with model gpt-4o
# Transforming questions document 178 with model gpt-4o
# Transforming questions document 179 with model gpt-4o
# Transforming questions document 180 with model gpt-4o
# Transforming questions document 181 with model gpt-4o
# Transforming questions document 182 with model gpt-4o
# Transforming questions document 183 with model gpt-4o
# Transforming questions document 184 with model gpt-4o
# Transforming questions document 185 with model gpt-4o
# Transforming questions document 186 with model gpt-4o
# Transforming questions document 187 with model gpt-4o
# Transforming questions document 188 with model gpt-4o
# Transforming questions document 189 with model gpt-4o
# Transforming questions document 190 with model gpt-4o
# Transforming questions document 191 with model gpt-4o
# Transforming questions document 192 with model gpt-4o
# Transforming questions document 193 with model gpt-4o
# Transforming questions document 194 with model gpt-4o
# Transforming questions document 195 with model gpt-4o
# Transforming questions document 196 with model gpt-4o
# Transforming questions document 197 with model gpt-4o
# Transforming questions document 198 with model gpt-4o
# Transforming questions document 199 with model gpt-4o
# Transforming questions document 200 with model gpt-4o
# Transforming questions document 201 with model gpt-4o
# Transforming questions document 202 with model gpt-4o
# Transforming questions document 203 with model gpt-4o
# Transforming questions document 204 with model gpt-4o
# Transforming questions document 205 with model gpt-4o
# Transforming questions document 206 with model gpt-4o
# Transforming questions document 207 with model gpt-4o
# Transforming questions document 208 with model gpt-4o
# Transforming questions document 209 with model gpt-4o
# Transforming questions document 210 with model gpt-4o
# Transforming questions document 211 with model gpt-4o
# Writing questions documents from model gpt-4o to file
# Transforming answers document 1 with model gpt-4o
# Transforming answers document 2 with model gpt-4o
# Transforming answers document 3 with model gpt-4o
# Transforming answers document 4 with model gpt-4o
# Transforming answers document 5 with model gpt-4o
# Transforming answers document 6 with model gpt-4o
# Transforming answers document 7 with model gpt-4o
# Transforming answers document 8 with model gpt-4o
# Transforming answers document 9 with model gpt-4o
# Transforming answers document 10 with model gpt-4o
# Transforming answers document 11 with model gpt-4o
# Transforming answers document 12 with model gpt-4o
# Transforming answers document 13 with model gpt-4o
# Transforming answers document 14 with model gpt-4o
# Transforming answers document 15 with model gpt-4o
# Transforming answers document 16 with model gpt-4o
# Transforming answers document 17 with model gpt-4o
# Transforming answers document 18 with model gpt-4o
# Transforming answers document 19 with model gpt-4o
# Transforming answers document 20 with model gpt-4o
# Transforming answers document 21 with model gpt-4o
# Transforming answers document 22 with model gpt-4o
# Transforming answers document 23 with model gpt-4o
# Transforming answers document 24 with model gpt-4o
# Transforming answers document 25 with model gpt-4o
# Transforming answers document 26 with model gpt-4o
# Transforming answers document 27 with model gpt-4o
# Transforming answers document 28 with model gpt-4o
# Transforming answers document 29 with model gpt-4o
# Transforming answers document 30 with model gpt-4o
# Transforming answers document 31 with model gpt-4o
# Transforming answers document 32 with model gpt-4o
# Transforming answers document 33 with model gpt-4o
# Transforming answers document 34 with model gpt-4o
# Transforming answers document 35 with model gpt-4o
# Transforming answers document 36 with model gpt-4o
# Transforming answers document 37 with model gpt-4o
# Transforming answers document 38 with model gpt-4o
# Transforming answers document 39 with model gpt-4o
# Transforming answers document 40 with model gpt-4o
# Transforming answers document 41 with model gpt-4o
# Transforming answers document 42 with model gpt-4o
# Transforming answers document 43 with model gpt-4o
# Transforming answers document 44 with model gpt-4o
# Transforming answers document 45 with model gpt-4o
# Transforming answers document 46 with model gpt-4o
# Transforming answers document 47 with model gpt-4o
# Transforming answers document 48 with model gpt-4o
# Transforming answers document 49 with model gpt-4o
# Transforming answers document 50 with model gpt-4o
# Transforming answers document 51 with model gpt-4o
# Transforming answers document 52 with model gpt-4o
# Transforming answers document 53 with model gpt-4o
# Transforming answers document 54 with model gpt-4o
# Transforming answers document 55 with model gpt-4o
# Transforming answers document 56 with model gpt-4o
# Transforming answers document 57 with model gpt-4o
# Transforming answers document 58 with model gpt-4o
# Transforming answers document 59 with model gpt-4o
# Transforming answers document 60 with model gpt-4o
# Transforming answers document 61 with model gpt-4o
# Transforming answers document 62 with model gpt-4o
# Transforming answers document 63 with model gpt-4o
# Transforming answers document 64 with model gpt-4o
# Transforming answers document 65 with model gpt-4o
# Transforming answers document 66 with model gpt-4o
# Transforming answers document 67 with model gpt-4o
# Transforming answers document 68 with model gpt-4o
# Transforming answers document 69 with model gpt-4o
# Transforming answers document 70 with model gpt-4o
# Transforming answers document 71 with model gpt-4o
# Transforming answers document 72 with model gpt-4o
# Transforming answers document 73 with model gpt-4o
# Transforming answers document 74 with model gpt-4o
# Transforming answers document 75 with model gpt-4o
# Transforming answers document 76 with model gpt-4o
# Transforming answers document 77 with model gpt-4o
# Transforming answers document 78 with model gpt-4o
# Transforming answers document 79 with model gpt-4o
# Transforming answers document 80 with model gpt-4o
# Transforming answers document 81 with model gpt-4o
# Transforming answers document 82 with model gpt-4o
# Transforming answers document 83 with model gpt-4o
# Transforming answers document 84 with model gpt-4o
# Transforming answers document 85 with model gpt-4o
# Transforming answers document 86 with model gpt-4o
# Transforming answers document 87 with model gpt-4o
# Transforming answers document 88 with model gpt-4o
# Transforming answers document 89 with model gpt-4o
# Transforming answers document 90 with model gpt-4o
# Transforming answers document 91 with model gpt-4o
# Transforming answers document 92 with model gpt-4o
# Transforming answers document 93 with model gpt-4o
# Transforming answers document 94 with model gpt-4o
# Transforming answers document 95 with model gpt-4o
# Transforming answers document 96 with model gpt-4o
# Transforming answers document 97 with model gpt-4o
# Transforming answers document 98 with model gpt-4o
# Transforming answers document 99 with model gpt-4o
# Transforming answers document 100 with model gpt-4o
# Transforming answers document 101 with model gpt-4o
# Transforming answers document 102 with model gpt-4o
# Transforming answers document 103 with model gpt-4o
# Transforming answers document 104 with model gpt-4o
# Transforming answers document 105 with model gpt-4o
# Transforming answers document 106 with model gpt-4o
# Transforming answers document 107 with model gpt-4o
# Transforming answers document 108 with model gpt-4o
# Transforming answers document 109 with model gpt-4o
# Transforming answers document 110 with model gpt-4o
# Transforming answers document 111 with model gpt-4o
# Transforming answers document 112 with model gpt-4o
# Transforming answers document 113 with model gpt-4o
# Transforming answers document 114 with model gpt-4o
# Transforming answers document 115 with model gpt-4o
# Transforming answers document 116 with model gpt-4o
# Transforming answers document 117 with model gpt-4o
# Transforming answers document 118 with model gpt-4o
# Transforming answers document 119 with model gpt-4o
# Transforming answers document 120 with model gpt-4o
# Transforming answers document 121 with model gpt-4o
# Transforming answers document 122 with model gpt-4o
# Transforming answers document 123 with model gpt-4o
# Transforming answers document 124 with model gpt-4o
# Transforming answers document 125 with model gpt-4o
# Transforming answers document 126 with model gpt-4o
# Transforming answers document 127 with model gpt-4o
# Transforming answers document 128 with model gpt-4o
# Transforming answers document 129 with model gpt-4o
# Transforming answers document 130 with model gpt-4o
# Transforming answers document 131 with model gpt-4o
# Transforming answers document 132 with model gpt-4o
# Transforming answers document 133 with model gpt-4o
# Transforming answers document 134 with model gpt-4o
# Transforming answers document 135 with model gpt-4o
# Transforming answers document 136 with model gpt-4o
# Transforming answers document 137 with model gpt-4o
# Transforming answers document 138 with model gpt-4o
# Transforming answers document 139 with model gpt-4o
# Transforming answers document 140 with model gpt-4o
# Transforming answers document 141 with model gpt-4o
# Transforming answers document 142 with model gpt-4o
# Transforming answers document 143 with model gpt-4o
# Transforming answers document 144 with model gpt-4o
# Transforming answers document 145 with model gpt-4o
# Transforming answers document 146 with model gpt-4o
# Transforming answers document 147 with model gpt-4o
# Transforming answers document 148 with model gpt-4o
# Transforming answers document 149 with model gpt-4o
# Transforming answers document 150 with model gpt-4o
# Transforming answers document 151 with model gpt-4o
# Transforming answers document 152 with model gpt-4o
# Transforming answers document 153 with model gpt-4o
# Transforming answers document 154 with model gpt-4o
# Transforming answers document 155 with model gpt-4o
# Transforming answers document 156 with model gpt-4o
# Transforming answers document 157 with model gpt-4o
# Transforming answers document 158 with model gpt-4o
# Transforming answers document 159 with model gpt-4o
# Transforming answers document 160 with model gpt-4o
# Transforming answers document 161 with model gpt-4o
# Transforming answers document 162 with model gpt-4o
# Transforming answers document 163 with model gpt-4o
# Transforming answers document 164 with model gpt-4o
# Transforming answers document 165 with model gpt-4o
# Transforming answers document 166 with model gpt-4o
# Transforming answers document 167 with model gpt-4o
# Transforming answers document 168 with model gpt-4o
# Transforming answers document 169 with model gpt-4o
# Transforming answers document 170 with model gpt-4o
# Transforming answers document 171 with model gpt-4o
# Transforming answers document 172 with model gpt-4o
# Transforming answers document 173 with model gpt-4o
# Transforming answers document 174 with model gpt-4o
# Transforming answers document 175 with model gpt-4o
# Transforming answers document 176 with model gpt-4o
# Transforming answers document 177 with model gpt-4o
# Transforming answers document 178 with model gpt-4o
# Transforming answers document 179 with model gpt-4o
# Transforming answers document 180 with model gpt-4o
# Transforming answers document 181 with model gpt-4o
# Transforming answers document 182 with model gpt-4o
# Transforming answers document 183 with model gpt-4o
# Transforming answers document 184 with model gpt-4o
# Transforming answers document 185 with model gpt-4o
# Transforming answers document 186 with model gpt-4o
# Transforming answers document 187 with model gpt-4o
# Transforming answers document 188 with model gpt-4o
# Transforming answers document 189 with model gpt-4o
# Transforming answers document 190 with model gpt-4o
# Transforming answers document 191 with model gpt-4o
# Transforming answers document 192 with model gpt-4o
# Transforming answers document 193 with model gpt-4o
# Transforming answers document 194 with model gpt-4o
# Transforming answers document 195 with model gpt-4o
# Transforming answers document 196 with model gpt-4o
# Transforming answers document 197 with model gpt-4o
# Transforming answers document 198 with model gpt-4o
# Transforming answers document 199 with model gpt-4o
# Transforming answers document 200 with model gpt-4o
# Transforming answers document 201 with model gpt-4o
# Transforming answers document 202 with model gpt-4o
# Transforming answers document 203 with model gpt-4o
# Transforming answers document 204 with model gpt-4o
# Transforming answers document 205 with model gpt-4o
# Transforming answers document 206 with model gpt-4o
# Transforming answers document 207 with model gpt-4o
# Transforming answers document 208 with model gpt-4o
# Transforming answers document 209 with model gpt-4o
# Transforming answers document 210 with model gpt-4o
# Transforming answers document 211 with model gpt-4o
# Writing answers documents from model gpt-4o to file
# Transforming summaries document 1 with model gpt-4o
# Transforming summaries document 2 with model gpt-4o
# Transforming summaries document 3 with model gpt-4o
# Transforming summaries document 4 with model gpt-4o
# Transforming summaries document 5 with model gpt-4o
# Transforming summaries document 6 with model gpt-4o
# Transforming summaries document 7 with model gpt-4o
# Transforming summaries document 8 with model gpt-4o
# Transforming summaries document 9 with model gpt-4o
# Transforming summaries document 10 with model gpt-4o
# Transforming summaries document 11 with model gpt-4o
# Transforming summaries document 12 with model gpt-4o
# Transforming summaries document 13 with model gpt-4o
# Transforming summaries document 14 with model gpt-4o
# Transforming summaries document 15 with model gpt-4o
# Transforming summaries document 16 with model gpt-4o
# Transforming summaries document 17 with model gpt-4o
# Transforming summaries document 18 with model gpt-4o
# Transforming summaries document 19 with model gpt-4o
# Transforming summaries document 20 with model gpt-4o
# Transforming summaries document 21 with model gpt-4o
# Transforming summaries document 22 with model gpt-4o
# Transforming summaries document 23 with model gpt-4o
# Transforming summaries document 24 with model gpt-4o
# Transforming summaries document 25 with model gpt-4o
# Transforming summaries document 26 with model gpt-4o
# Transforming summaries document 27 with model gpt-4o
# Transforming summaries document 28 with model gpt-4o
# Transforming summaries document 29 with model gpt-4o
# Transforming summaries document 30 with model gpt-4o
# Transforming summaries document 31 with model gpt-4o
# Transforming summaries document 32 with model gpt-4o
# Transforming summaries document 33 with model gpt-4o
# Transforming summaries document 34 with model gpt-4o
# Transforming summaries document 35 with model gpt-4o
# Transforming summaries document 36 with model gpt-4o
# Transforming summaries document 37 with model gpt-4o
# Transforming summaries document 38 with model gpt-4o
# Transforming summaries document 39 with model gpt-4o
# Transforming summaries document 40 with model gpt-4o
# Transforming summaries document 41 with model gpt-4o
# Transforming summaries document 42 with model gpt-4o
# Transforming summaries document 43 with model gpt-4o
# Transforming summaries document 44 with model gpt-4o
# Transforming summaries document 45 with model gpt-4o
# Transforming summaries document 46 with model gpt-4o
# Transforming summaries document 47 with model gpt-4o
# Transforming summaries document 48 with model gpt-4o
# Transforming summaries document 49 with model gpt-4o
# Transforming summaries document 50 with model gpt-4o
# Transforming summaries document 51 with model gpt-4o
# Transforming summaries document 52 with model gpt-4o
# Transforming summaries document 53 with model gpt-4o
# Transforming summaries document 54 with model gpt-4o
# Transforming summaries document 55 with model gpt-4o
# Transforming summaries document 56 with model gpt-4o
# Transforming summaries document 57 with model gpt-4o
# Transforming summaries document 58 with model gpt-4o
# Transforming summaries document 59 with model gpt-4o
# Transforming summaries document 60 with model gpt-4o
# Transforming summaries document 61 with model gpt-4o
# Transforming summaries document 62 with model gpt-4o
# Transforming summaries document 63 with model gpt-4o
# Transforming summaries document 64 with model gpt-4o
# Transforming summaries document 65 with model gpt-4o
# Transforming summaries document 66 with model gpt-4o
# Transforming summaries document 67 with model gpt-4o
# Transforming summaries document 68 with model gpt-4o
# Transforming summaries document 69 with model gpt-4o
# Transforming summaries document 70 with model gpt-4o
# Transforming summaries document 71 with model gpt-4o
# Transforming summaries document 72 with model gpt-4o
# Transforming summaries document 73 with model gpt-4o
# Transforming summaries document 74 with model gpt-4o
# Transforming summaries document 75 with model gpt-4o
# Transforming summaries document 76 with model gpt-4o
# Transforming summaries document 77 with model gpt-4o
# Transforming summaries document 78 with model gpt-4o
# Transforming summaries document 79 with model gpt-4o
# Transforming summaries document 80 with model gpt-4o
# Transforming summaries document 81 with model gpt-4o
# Transforming summaries document 82 with model gpt-4o
# Transforming summaries document 83 with model gpt-4o
# Transforming summaries document 84 with model gpt-4o
# Transforming summaries document 85 with model gpt-4o
# Transforming summaries document 86 with model gpt-4o
# Transforming summaries document 87 with model gpt-4o
# Transforming summaries document 88 with model gpt-4o
# Transforming summaries document 89 with model gpt-4o
# Transforming summaries document 90 with model gpt-4o
# Transforming summaries document 91 with model gpt-4o
# Transforming summaries document 92 with model gpt-4o
# Transforming summaries document 93 with model gpt-4o
# Transforming summaries document 94 with model gpt-4o
# Transforming summaries document 95 with model gpt-4o
# Transforming summaries document 96 with model gpt-4o
# Transforming summaries document 97 with model gpt-4o
# Transforming summaries document 98 with model gpt-4o
# Transforming summaries document 99 with model gpt-4o
# Transforming summaries document 100 with model gpt-4o
# Transforming summaries document 101 with model gpt-4o
# Transforming summaries document 102 with model gpt-4o
# Transforming summaries document 103 with model gpt-4o
# Transforming summaries document 104 with model gpt-4o
# Transforming summaries document 105 with model gpt-4o
# Transforming summaries document 106 with model gpt-4o
# Transforming summaries document 107 with model gpt-4o
# Transforming summaries document 108 with model gpt-4o
# Transforming summaries document 109 with model gpt-4o
# Transforming summaries document 110 with model gpt-4o
# Transforming summaries document 111 with model gpt-4o
# Transforming summaries document 112 with model gpt-4o
# Transforming summaries document 113 with model gpt-4o
# Transforming summaries document 114 with model gpt-4o
# Transforming summaries document 115 with model gpt-4o
# Transforming summaries document 116 with model gpt-4o
# Transforming summaries document 117 with model gpt-4o
# Transforming summaries document 118 with model gpt-4o
# Transforming summaries document 119 with model gpt-4o
# Transforming summaries document 120 with model gpt-4o
# Transforming summaries document 121 with model gpt-4o
# Transforming summaries document 122 with model gpt-4o
# Transforming summaries document 123 with model gpt-4o
# Transforming summaries document 124 with model gpt-4o
# Transforming summaries document 125 with model gpt-4o
# Transforming summaries document 126 with model gpt-4o
# Transforming summaries document 127 with model gpt-4o
# Transforming summaries document 128 with model gpt-4o
# Transforming summaries document 129 with model gpt-4o
# Transforming summaries document 130 with model gpt-4o
# Transforming summaries document 131 with model gpt-4o
# Transforming summaries document 132 with model gpt-4o
# Transforming summaries document 133 with model gpt-4o
# Transforming summaries document 134 with model gpt-4o
# Transforming summaries document 135 with model gpt-4o
# Transforming summaries document 136 with model gpt-4o
# Transforming summaries document 137 with model gpt-4o
# Transforming summaries document 138 with model gpt-4o
# Transforming summaries document 139 with model gpt-4o
# Transforming summaries document 140 with model gpt-4o
# Transforming summaries document 141 with model gpt-4o
# Transforming summaries document 142 with model gpt-4o
# Transforming summaries document 143 with model gpt-4o
# Transforming summaries document 144 with model gpt-4o
# Transforming summaries document 145 with model gpt-4o
# Transforming summaries document 146 with model gpt-4o
# Transforming summaries document 147 with model gpt-4o
# Transforming summaries document 148 with model gpt-4o
# Transforming summaries document 149 with model gpt-4o
# Transforming summaries document 150 with model gpt-4o
# Transforming summaries document 151 with model gpt-4o
# Transforming summaries document 152 with model gpt-4o
# Transforming summaries document 153 with model gpt-4o
# Transforming summaries document 154 with model gpt-4o
# Transforming summaries document 155 with model gpt-4o
# Transforming summaries document 156 with model gpt-4o
# Transforming summaries document 157 with model gpt-4o
# Transforming summaries document 158 with model gpt-4o
# Transforming summaries document 159 with model gpt-4o
# Transforming summaries document 160 with model gpt-4o
# Transforming summaries document 161 with model gpt-4o
# Transforming summaries document 162 with model gpt-4o
# Transforming summaries document 163 with model gpt-4o
# Transforming summaries document 164 with model gpt-4o
# Transforming summaries document 165 with model gpt-4o
# Transforming summaries document 166 with model gpt-4o
# Transforming summaries document 167 with model gpt-4o
# Transforming summaries document 168 with model gpt-4o
# Transforming summaries document 169 with model gpt-4o
# Transforming summaries document 170 with model gpt-4o
# Transforming summaries document 171 with model gpt-4o
# Transforming summaries document 172 with model gpt-4o
# Transforming summaries document 173 with model gpt-4o
# Transforming summaries document 174 with model gpt-4o
# Transforming summaries document 175 with model gpt-4o
# Transforming summaries document 176 with model gpt-4o
# Transforming summaries document 177 with model gpt-4o
# Transforming summaries document 178 with model gpt-4o
# Transforming summaries document 179 with model gpt-4o
# Transforming summaries document 180 with model gpt-4o
# Transforming summaries document 181 with model gpt-4o
# Transforming summaries document 182 with model gpt-4o
# Transforming summaries document 183 with model gpt-4o
# Transforming summaries document 184 with model gpt-4o
# Transforming summaries document 185 with model gpt-4o
# Transforming summaries document 186 with model gpt-4o
# Transforming summaries document 187 with model gpt-4o
# Transforming summaries document 188 with model gpt-4o
# Transforming summaries document 189 with model gpt-4o
# Transforming summaries document 190 with model gpt-4o
# Transforming summaries document 191 with model gpt-4o
# Transforming summaries document 192 with model gpt-4o
# Transforming summaries document 193 with model gpt-4o
# Transforming summaries document 194 with model gpt-4o
# Transforming summaries document 195 with model gpt-4o
# Transforming summaries document 196 with model gpt-4o
# Transforming summaries document 197 with model gpt-4o
# Transforming summaries document 198 with model gpt-4o
# Transforming summaries document 199 with model gpt-4o
# Transforming summaries document 200 with model gpt-4o
# Transforming summaries document 201 with model gpt-4o
# Transforming summaries document 202 with model gpt-4o
# Transforming summaries document 203 with model gpt-4o
# Transforming summaries document 204 with model gpt-4o
# Transforming summaries document 205 with model gpt-4o
# Transforming summaries document 206 with model gpt-4o
# Transforming summaries document 207 with model gpt-4o
# Transforming summaries document 208 with model gpt-4o
# Transforming summaries document 209 with model gpt-4o
# Transforming summaries document 210 with model gpt-4o
# Transforming summaries document 211 with model gpt-4o
# Writing summaries documents from model gpt-4o to file

# %% [markdown]
# ## Prepare Embeddings model

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = None

if embedding_source == "openai":
    embeddings = OpenAIEmbeddings(model=embeddings_model)

# %% [markdown]
# ## Prepare store

# %%
from langchain.vectorstores import Qdrant

def store(documents, collection_name):
    Qdrant.from_documents(
        documents,
        url="http://localhost:6333",
        embedding=embeddings,
        collection_name=collection_name,
        force_recreate=True,
    )

pure_collection = f"{embeddings_model}-{llm_model}-p"
question_collection = f"{embeddings_model}-{llm_model}-q"
answer_collection = f"{embeddings_model}-{llm_model}-a"
summary_collection = f"{embeddings_model}-{llm_model}-s"

collections = [pure_collection, question_collection, answer_collection, summary_collection]

# %% [markdown]
# ## Create embeddings and store them in different collections

# %%
if reindex_documents:
    store(split_documents, pure_collection)
    store(question_documents, question_collection)
    store(answer_documents, answer_collection)
    store(summary_documents, summary_collection)

# %% [markdown]
# ## Search with a query in the different indexes

# %% [markdown]
# You can look at the Qudrant collections and data at http://localhost:6333/dashboard

# %%
queries = [
    "Was mache ich, wenn ich meinen letzten Zug verpasst habe?",
    "Nach wie vielen Jahren kann ich mein Notebook erneuern?",
    "Was ist MITOD?",
]

# %%
from qdrant_client import QdrantClient

client = QdrantClient("http://localhost:6333")

def search(collection, query):
    return Qdrant(client, collection, embeddings)._similarity_search_with_relevance_scores(query)

collections = [pure_collection, question_collection, answer_collection, summary_collection]

result_table = []
result_table.append(["Collection"] + queries)

for collection in collections:
    row = []
    for query in queries:
        print(f"Searching {collection} for {query}")
        search_results = search(collection, query)

        row.append("\n".join([f"{document.metadata['index']} - {score}" for document, score in search_results]))

    result_table.append([collection] + row)
# Out:
# Searching text-embedding-3-large-gpt-4o-p for Was mache ich, wenn ich meinen letzten Zug verpasst habe?
# /var/folders/5l/mksr7zj10lgb4y62_h1x1nxc0000gn/T/ipykernel_79266/1941515052.py:6: LangChainDeprecationWarning: The class `Qdrant` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-qdrant package and should be used instead. To use it run `pip install -U :class:`~langchain-qdrant` and import as `from :class:`~langchain_qdrant import Qdrant``.
#   return Qdrant(client, collection, embeddings)._similarity_search_with_relevance_scores(query)
# Searching text-embedding-3-large-gpt-4o-p for Nach wie vielen Jahren kann ich mein Notebook erneuern?
# Searching text-embedding-3-large-gpt-4o-p for Was ist MITOD?
# Searching text-embedding-3-large-gpt-4o-q for Was mache ich, wenn ich meinen letzten Zug verpasst habe?
# Searching text-embedding-3-large-gpt-4o-q for Nach wie vielen Jahren kann ich mein Notebook erneuern?
# Searching text-embedding-3-large-gpt-4o-q for Was ist MITOD?
# Searching text-embedding-3-large-gpt-4o-a for Was mache ich, wenn ich meinen letzten Zug verpasst habe?
# Searching text-embedding-3-large-gpt-4o-a for Nach wie vielen Jahren kann ich mein Notebook erneuern?
# Searching text-embedding-3-large-gpt-4o-a for Was ist MITOD?
# Searching text-embedding-3-large-gpt-4o-s for Was mache ich, wenn ich meinen letzten Zug verpasst habe?
# Searching text-embedding-3-large-gpt-4o-s for Nach wie vielen Jahren kann ich mein Notebook erneuern?
# Searching text-embedding-3-large-gpt-4o-s for Was ist MITOD?

# %%
from tabulate import tabulate

print(tabulate(result_table, tablefmt="grid", headers="firstrow"))
# Out:
# +---------------------------------+-------------------------------------------------------------+-----------------------------------------------------------+------------------+
# | Collection                      | Was mache ich, wenn ich meinen letzten Zug verpasst habe?   | Nach wie vielen Jahren kann ich mein Notebook erneuern?   | Was ist MITOD?   |
# +=================================+=============================================================+===========================================================+==================+
# | text-embedding-3-large-gpt-4o-p | 198 - 0.5888042                                             | 100 - 0.36935392                                          | 140 - 0.51360524 |
# |                                 | 200 - 0.45595053                                            | 160 - 0.36125535                                          | 139 - 0.45612168 |
# |                                 | 197 - 0.37155625                                            | 159 - 0.3516118                                           | 41 - 0.3039658   |
# |                                 | 199 - 0.36761343                                            | 99 - 0.33544755                                           | 167 - 0.28293365 |
# +---------------------------------+-------------------------------------------------------------+-----------------------------------------------------------+------------------+
# | text-embedding-3-large-gpt-4o-q | 198 - 0.66212094                                            | 100 - 0.40724835                                          | 140 - 0.5335345  |
# |                                 | 200 - 0.37082493                                            | 159 - 0.34521842                                          | 139 - 0.4630633  |
# |                                 | 175 - 0.3514755                                             | 160 - 0.3236413                                           | 83 - 0.27010527  |
# |                                 | 173 - 0.34900844                                            | 24 - 0.32190022                                           | 136 - 0.2612373  |
# +---------------------------------+-------------------------------------------------------------+-----------------------------------------------------------+------------------+
# | text-embedding-3-large-gpt-4o-a | 198 - 0.6640717                                             | 100 - 0.36071026                                          | 139 - 0.39667588 |
# |                                 | 200 - 0.43197408                                            | 159 - 0.33870995                                          | 140 - 0.38942775 |
# |                                 | 199 - 0.34644297                                            | 200 - 0.3067721                                           | 1 - 0.30959705   |
# |                                 | 197 - 0.3396101                                             | 99 - 0.30436948                                           | 41 - 0.28433886  |
# +---------------------------------+-------------------------------------------------------------+-----------------------------------------------------------+------------------+
# | text-embedding-3-large-gpt-4o-s | 198 - 0.6061536                                             | 100 - 0.37124068                                          | 139 - 0.5053238  |
# |                                 | 200 - 0.43064627                                            | 159 - 0.35609794                                          | 140 - 0.39252684 |
# |                                 | 197 - 0.37113604                                            | 99 - 0.32559323                                           | 41 - 0.32104814  |
# |                                 | 195 - 0.32751808                                            | 200 - 0.30001572                                          | 13 - 0.29093632  |
# +---------------------------------+-------------------------------------------------------------+-----------------------------------------------------------+------------------+

# %% [markdown]
# # To check a result, put the index in the following cell and run it

# %%
found_index = 156

# find the document with the metadata index of the found_index variable

found_document = None
for doc in split_documents:
    if doc.metadata["index"] == found_index:
        found_document = doc
        break

print(f'{found_document.page_content}\n\n')
print(f'{found_document.metadata}\n\n')

for doc in question_documents:
    if doc.metadata["index"] == found_index:
        found_document = doc
        break

print(f"Questions: {found_document.page_content}\n\n")

for doc in answer_documents:
    if doc.metadata["index"] == found_index:
        found_document = doc
        break

print(f"Answers: {found_document.page_content}\n\n")

for doc in summary_documents:
    if doc.metadata["index"] == found_index:
        found_document = doc
        break

print(f"Summary: {found_document.page_content}\n\n")
